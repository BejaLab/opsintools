# %% [markdown]
# ## OpsinPDB
#
# OpsinPDB fetches a PDB record or reads user-provided PDB and CIF files, cleans them and saves as a PDB file. The cleanup includes renaming the atoms of `LYR` (= `LYS+RET`), removing non-covalent ligands, water molecules, hydrogens, alternative states and unwanted chains.

# %%
#@title Inputs

#@markdown 1. Either upload your existing PDB files:
#@markdown * Open the 🗀 Files panel to the left
#@markdown * Upload your pdb file(s) in the root directory

#@markdown &nbsp;&nbsp;&nbsp;&nbsp;&nbsp; Or fetch from PDB:
ACCESSIONS = "" # @param {"type":"string"}

#@markdown 2. Adjust the settings if needed:
CHAINS = "" # @param {"type":"string"}
#@markdown &nbsp;&nbsp;&nbsp;&nbsp;&nbsp; ↳ _Comma-separated list of chains_
RETAIN_LIGANDS = "" # @param {"type":"string"}
#@markdown &nbsp;&nbsp;&nbsp;&nbsp;&nbsp; ↳ _Comma-separated list of **non-covalent** ligands to **retain** (all removed by default)_
REMOVE_LIGANDS = "" # @param {"type":"string"}
#@markdown &nbsp;&nbsp;&nbsp;&nbsp;&nbsp; ↳ _Comma-separated list of **covalent** ligands to **remove** (none removed by default)_
REMAP_LYR = True # @param {"type":"boolean"}
#@markdown &nbsp;&nbsp;&nbsp;&nbsp;&nbsp; ↳ _Whether to re-map LYR atoms (split into LYS and RET)_
REMOVE_H = True # @param {"type":"boolean"}
REMOVE_W = True # @param {"type":"boolean"}
#@markdown &nbsp;&nbsp;&nbsp;&nbsp;&nbsp; ↳ _Whether to remove hydrogens and waters_
REMOVE_ALT = True # @param {"type":"boolean"}
#@markdown &nbsp;&nbsp;&nbsp;&nbsp;&nbsp; ↳ _Whether to remove alternative conformations_

#@markdown 3. Press `▹ Run all` to run the workflow

# Check the inputs

import re
from pathlib import Path

ACCESSIONS = re.sub(r"\s", "", ACCESSIONS.upper()).split(',')
CHAINS = re.sub(r"\s", "", CHAINS.upper())
RETAIN_LIGANDS = re.sub(r"\s", "", RETAIN_LIGANDS.upper())
REMOVE_LIGANDS = re.sub(r"\s", "", REMOVE_LIGANDS.upper())

PDB_FILES = []
for ext in [ 'pdb', 'cif' ]:
    for pdb_file in Path('.').glob('*.' + ext, case_sensitive = False):
        PDB_FILES.append(pdb_file)

if not PDB_FILES and not ACCESSIONS:
    raise FileNotFoundError(f"No PDB files found in the folder and no accession provided")

# Environment variables

import os

ROOT = "/content/mmb"

os.environ['MAMBA_ROOT_PREFIX'] = ROOT
os.environ['PATH'] = f":{ROOT}/bin:{ROOT}/condabin:/content/bin/:" + os.environ['PATH']
os.environ['CONDA_PREFIX'] = ROOT
os.environ['CONDA_SHLVL'] = '1'
os.environ['CONDA_DEFAULT_ENV'] = 'base'
os.environ['CONDA_PROMPT_MODIFIER'] = 'base'

# %%
#@title Setup the environment

# %%bash

ENV_DIR=/content/mmb/envs/env

if [ ! -s /usr/bin/micromamba ]; then
    echo "Downloading micromamba"
    url=https://micro.mamba.pm/api/micromamba/linux-64/latest
    wget -qO- $url | tar -C /usr/ -xj bin/micromamba &
fi
if [ -z "$(command -v zstd)" ]; then
    echo "Installing zstd"
    apt install -y zstd &> /dev/null
fi
wait
if [ ! -d $ENV_DIR ]; then
    echo "Setting up the environmemt"
    mkdir -p $ENV_DIR
    url=https://github.com/BejaLab/opsintools/releases/download/v0.5-beta/opsintools-v0.5-beta_conda_env_linux-64.tar.zst
    wget -qO- $url | tar -I "zstd -T4" -xf - -C $ENV_DIR
    (cd $ENV_DIR && ./bin/conda-unpack)
fi
if [ ! -d data ]; then
    micromamba run -n env opsindata -d data
fi

# %%
#@title Run the pipeline

from pathlib import Path
import sys

args = []

if CHAINS:
  args += [ "-c", CHAINS ]

flags = []
if RETAIN_LIGANDS:
  args += [ "--ligands", RETAIN_LIGANDS ]

if REMOVE_LIGANDS:
  args += [ "--ligands-remove", REMOVE_LIGANDS ]
if not REMAP_LYR:
  args += [ "--L" ]
if not REMOVE_W:
  args += [ "--W " ]
if not REMOVE_H:
  args += [ "--H" ]
if not REMOVE_ALT:
  args += [ "--A" ]

args_str = " ".join(args)

output_path = Path('output')
output_path.mkdir(exist_ok = True)

for pdb_file in PDB_FILES:
    this_output_path = output_path / pdb_file.name
    # !micromamba run -n env opsinpdb -i {pdb_file} -o {this_output_path} {args_str}

for acc in ACCESSIONS:
    this_output_path = output_path / f"{acc}.pdb"
    # !micromamba run -n env opsinpdb -a {acc} -o {this_output_path} {args_str}

# %%
#@title Output

from google.colab import files
import shutil
from pprint import pprint

shutil.make_archive('opsinpdb_output', 'zip', 'output')
files.download("opsinpdb_output.zip")
