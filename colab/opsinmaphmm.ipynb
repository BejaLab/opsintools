# %% [markdown]
# ## OpsinMapHMM
#
# Opsin homology using protein profiles. Maps residues in each query to the reference using alignment to a set of opsin profiles.

# %%
#@title Inputs

#@markdown 1. Open the `🗀 Files` panel to the left
#@markdown 2. Upload your query fasta file(s) in the root directory.
#@markdown 3. Optionally, adjust parameters if needed:
PAD_N = 30 # @param {"type":"integer"}
PAD_C = 30 # @param {"type":"integer"}
#@markdown &nbsp;&nbsp;&nbsp;&nbsp;&nbsp; ↳ _padding (residues added to trimmed domain sequence):_
MIN_SCORE = 15 # @param {"type":"integer"}
#@markdown &nbsp;&nbsp;&nbsp;&nbsp;&nbsp; ↳ _the minimum score (the default might result in false positives if the sequences are not rhodopsins)_

#@markdown 4. Press `▹ Run all` to run the workflow

# Check in the inputs

from pathlib import Path

FASTA_FILES = list(Path('.').glob('*.fa*', case_sensitive=False))
if not FASTA_FILES:
    raise FileNotFoundError(f"No fasta files found in the folder")

# Environment variables

import os

ROOT = "/content/mmb"

os.environ['MAMBA_ROOT_PREFIX'] = ROOT
os.environ['PATH'] = f":{ROOT}/bin:{ROOT}/condabin:/content/bin/:" + os.environ['PATH']
os.environ['CONDA_PREFIX'] = ROOT
os.environ['CONDA_SHLVL'] = '1'
os.environ['CONDA_DEFAULT_ENV'] = 'base'
os.environ['CONDA_PROMPT_MODIFIER'] = 'base'

# %%
#@title Setup the environment

# %%bash

ENV_DIR=/content/mmb/envs/env

if [ ! -s /usr/bin/micromamba ]; then
    echo "Downloading micromamba"
    url=https://micro.mamba.pm/api/micromamba/linux-64/latest
    wget -qO- $url | tar -C /usr/ -xj bin/micromamba &
fi
if [ -z "$(command -v zstd)" ]; then
    echo "Installing zstd"
    apt install -y zstd &> /dev/null
fi
wait
if [ ! -d $ENV_DIR ]; then
    echo "Setting up the environmemt"
    mkdir -p $ENV_DIR
    url=https://github.com/BejaLab/opsintools/releases/download/v0.5-beta/opsintools-v0.5-beta_conda_env_linux-64.tar.zst
    wget -qO- $url | tar -I "zstd -T4" -xf - -C $ENV_DIR
    (cd $ENV_DIR && ./bin/conda-unpack)
fi
if [ ! -d data ]; then
    micromamba run -n env opsindata -d data
fi

# %%
#@title Run the pipeline

from pathlib import Path
import sys

OUTPUT_PATH = Path('output')
OUTPUT_PATH.mkdir(exist_ok = True)
DATA_PATH = next(Path('data').glob('*'))

for fasta_file in FASTA_FILES:
    this_output_path = OUTPUT_PATH / fasta_file.name
    # !micromamba run -n env opsinmaphmm -f -i {fasta_file} -t 2 -o {this_output_path} -d {DATA_PATH}/* --pad-n {PAD_N} --pad-c {PAD_C} --min-score {MIN_SCORE}
    if _exit_code:
        pass

# %%
#@title Output

colab_utils_path = Path("colab_utils.py")
if not colab_utils_path.exists():
  import urllib.request
  urllib.request.urlretrieve(url = "https://raw.githubusercontent.com/BejaLab/opsintools/refs/heads/main/colab/colab_utils.ipynb", filename = colab_utils_path)

from google.colab import files
import shutil
import colab_utils

colab_utils.generate_html_report(OUTPUT_PATH, DATA_PATH)
shutil.make_archive('opsinmaphmm_output', 'zip', 'output')
files.download("opsinmaphmm_output.zip")
